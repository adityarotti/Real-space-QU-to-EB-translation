# %%
import healpy as h
import sys  ; sys.path.append("../../codes/")
#from modules import calc_spinylm as sylm
#from modules import local_eb_kernel as rko
from modules_v2 import euler as euler
from modules_v1 import aliasing_correction as ac

# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
b2,a2,g2,s2=ac.return_euler_angles(8,100)
cb1,c2a,s2a,s1=euler.fn_euler_trig2alpha(8,100)
h.mollview(c2a-cos(2.*a2))
h.mollview(s2a+sin(2.*a2))
# Out:
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
b2,a2,g2,s2=ac.return_euler_angles(8,0)
cb1,c2g,s2g,s1=euler.fn_euler_trig2gamma(8,0)
h.mollview(c2g-cos(2.*g2))
h.mollview(s2g+sin(2.*g2))
# Out:
# ../../codes/modules_v2/euler.py:51: RuntimeWarning: divide by zero encountered in divide
#   singamma=np.where(abs(cosbeta)<1.,-np.sin(theta0)*np.sin(phi1-phi0)/np.sqrt(1.-cosbeta*cosbeta),0.)
# ../../codes/modules_v2/euler.py:51: RuntimeWarning: invalid value encountered in divide
#   singamma=np.where(abs(cosbeta)<1.,-np.sin(theta0)*np.sin(phi1-phi0)/np.sqrt(1.-cosbeta*cosbeta),0.)
# ../../codes/modules_v2/euler.py:52: RuntimeWarning: invalid value encountered in divide
#   cosgamma=np.where(abs(cosbeta)<1.,(np.cos(theta0) - cosbeta*np.cos(theta1))/(np.sin(theta1)*np.sqrt(1.-cosbeta*cosbeta)),1.)
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
b2,a2,g2,s2=ac.return_euler_angles(8,20)
cb1,c2amg,s2amg,s1=euler.fn_euler_trig2_alpha_minus_gamma(8,20)
h.mollview(c2amg-cos(2.*(a2-g2)))
h.mollview(s2amg+sin(2.*(a2-g2)))
# Out:
# ../../codes/modules_v2/euler.py:92: RuntimeWarning: divide by zero encountered in divide
#   sinalpha=np.where(abs(cosbeta)<1.,np.sin(theta1)*np.sin(phi1-phi0)/np.sqrt(1.-cosbeta*cosbeta),0.)
# ../../codes/modules_v2/euler.py:92: RuntimeWarning: invalid value encountered in divide
#   sinalpha=np.where(abs(cosbeta)<1.,np.sin(theta1)*np.sin(phi1-phi0)/np.sqrt(1.-cosbeta*cosbeta),0.)
# ../../codes/modules_v2/euler.py:93: RuntimeWarning: invalid value encountered in divide
#   cosalpha=np.where(abs(cosbeta)<1.,(np.cos(theta0)*cosbeta - np.cos(theta1))/(np.sin(theta0)*np.sqrt(1.-cosbeta*cosbeta)),1.)
# ../../codes/modules_v2/euler.py:94: RuntimeWarning: divide by zero encountered in divide
#   singamma=np.where(abs(cosbeta)<1.,-np.sin(theta0)*np.sin(phi1-phi0)/np.sqrt(1.-cosbeta*cosbeta),0.)
# ../../codes/modules_v2/euler.py:94: RuntimeWarning: invalid value encountered in divide
#   singamma=np.where(abs(cosbeta)<1.,-np.sin(theta0)*np.sin(phi1-phi0)/np.sqrt(1.-cosbeta*cosbeta),0.)
# ...

# %%
b2,a2,g2,s2=ac.return_euler_angles(8,100)
cb1,c2apg,s2apg,s1=euler.fn_euler_trig2_alpha_plus_gamma(8,100)
h.mollview(c2apg-cos(2.*(a2+g2)))
h.mollview(s2apg+sin(2.*(a2+g2)))
# Out:
# ../../codes/modules_v2/euler.py:70: RuntimeWarning: divide by zero encountered in divide
#   cosalpha=np.where(abs(cosbeta)<1.,(np.cos(theta0)*cosbeta - np.cos(theta1))/(np.sin(theta0)*np.sqrt(1.-cosbeta*cosbeta)),1.)
# ../../codes/modules_v2/euler.py:72: RuntimeWarning: divide by zero encountered in divide
#   cosgamma=np.where(abs(cosbeta)<1.,(np.cos(theta0) - cosbeta*np.cos(theta1))/(np.sin(theta1)*np.sqrt(1.-cosbeta*cosbeta)),1.)
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
max(abs(c2apg-cos(2.*(a2+g2))))
# Out:
# 2.5091040356528538e-14
