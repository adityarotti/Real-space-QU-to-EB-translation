# %%
import healpy as h
import sys  ; sys.path.append("../../codes/")
from modules import radial_kernel as rk
from scipy.integrate import quad
import timeit

figpath="./article/figures/"

# %%
from matplotlib import rcParams,rc
params = {'backend': 'pdf',
          'savefig.dpi': 200,
          'axes.labelsize': 15,
          'text.fontsize': 15,
          'axes.linewidth' : 2,
          'lines.linewidth' : 2,
          'font.size': 15,
          'xtick.labelsize': 15,
          'ytick.major.pad': 6,
          'xtick.major.pad': 6,
          'ytick.labelsize': 15,
          'text.usetex': True,
          'font.family':'sans-serif',
          'font.sans-serif':'FreeSans'}
rc('text.latex', preamble='\usepackage{sfmath}')
rcParams.update(params)
# Out:
# /Users/adityarotti/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: text.fontsize is deprecated and replaced with font.size; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
nside=32; upnside=2048 ; npix=h.nside2npix(upnside)
lmax=3*nside ; lmin=2

odisc=min(180.,180.*(12./lmax)*1.2)
print odisc

y=rk.real_space_queb_kernels(nside,tmax=odisc,maxlmax=6*nside,sampling=800)
y.setup_qu2eb_rad_kernel(lmax,lmin)
y.setup_qu2queb_rad_kernel(lmax,lmin)
# Out:
# 27.0

# %%
# make plots of Mr and Mi
mr=zeros(npix,float) ; mi=zeros(npix,float)
Ir=zeros(npix,float) ; Ii=zeros(npix,float)
Jr=zeros(npix,float) ; Ji=zeros(npix,float)

lat=120. ; lon=90.
i=h.ang2pix(upnside,lat*pi/180.,lon*pi/180.)
a,b,g,pix2=y.return_euler_angles(upnside,i,odisc)
mr[pix2]=cos(2.*a)*y.fn_rad_ker(b) ; mi[pix2]=-sin(2.*a)*y.fn_rad_ker(b)
Ir[pix2]=cos(2.*(a+g))*y.fn_rad_ker_m2(b) ; Ii[pix2]=-sin(2.*(a+g))*y.fn_rad_ker_m2(b)
Jr[pix2]=cos(2.*(a-g))*y.fn_rad_ker_p2(b) ; Ji[pix2]=sin(2.*(a-g))*y.fn_rad_ker_p2(b)

# %%
xsize=400  ; reso=(odisc*60.)/xsize ; grat=2. ; print reso
# Out:
# 4.05

# %%
tmap=Jr ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.2f")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot(0.*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "qu2ebqu_ker_r_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")

tmap=Ji ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.2f")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot((0)*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "qu2ebqu_ker_i_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")
# Out:
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.

# %%
tmap=mr ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.2f")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot(0.*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "qu2eb_ker_r_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")

tmap=mi ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.2f")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot((0)*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "qu2eb_ker_i_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")
# Out:
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.

# %%
tmap=Ir ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.2f")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot(0.*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "I_ker_r_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")

tmap=Ii ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.2f")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot((0)*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "I_ker_i_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")
# Out:
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.

# %%
tmap=Ii ; vmin=min(tmap) ; vmax=max(tmap)
h.gnomview(tmap,rot=(lon,90-lat),xsize=xsize,ysize=xsize,reso=reso,title="",min=vmin,max=vmax,notext=True,cbar=None)
h.graticule(dpar=grat,dmer=grat,linestyle="dashed",alpha=0.4)
fig = gcf() ; ax = gca() ; image = ax.get_images()[0]
cmap = fig.colorbar(image,orientation="horizontal",shrink=0.6,pad=-0.04,ticks=linspace(vmin,vmax,4),format="%.1e")
cmap.solids.set_edgecolor("face")
text(0.15,-0.175,r"$b=" + str(round(90-lat,1)) + "^\circ$",fontsize=12)
text(0.152,-0.155,r"$\ell=" + str(round(lon,1)) + "^\circ$",fontsize=12)
h.projplot((0)*np.pi/180,0.*np.pi/180,"*",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
h.projplot(lat*np.pi/180,lon*np.pi/180,"o",color="white",markersize=6,markeredgecolor="black",fillstyle="none",markeredgewidth=1.)
savefig(figpath + "I_ker_i_lat" + str(int(90-lat)) + "_lon" + str(int(lon)) + ".pdf",dpi=300,bbox_inches="tight")
# Out:
# 71.6140609432 108.385939057 -18.3859390568 18.3859390568
# The interval between parallels is 4 deg 0.00'.
# The interval between meridians is 2 deg 0.00'.

# %%
# Out:
# 26
