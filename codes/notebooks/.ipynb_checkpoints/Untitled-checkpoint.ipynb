# %%
import healpy as h
import sys  ; sys.path.append("../../codes/")
from modules import local_eb_kernel_masked as rk
from scipy.integrate import quad
import timeit
from scipy.interpolate import interp1d
from scipy.special import lpmn as lpmn

# %pylab notebook
import time

from scipy.special import sph_harm as sph

from sympy.physics.quantum.spin import Rotation
from sympy import N
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['mat']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
costheta=h.ringinfo(nside,arange(4*nside-1)+1)[2]

# %%
mat=lpmn(128,128,costheta[1])[0]

# %%
l=254 ; m=0
np.sqrt(float(math.factorial(l-m))/float(math.factorial(l+m)))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-127-4b07229baa52> in <module>()
#       1 l=254 ; m=0
# ----> 2 np.sqrt(float(math.factorial(l-m))/float(math.factorial(l+m)))
#
# OverflowError: long int too large to convert to float

# %%
nside=2 ; upnside=nside ; npix=h.nside2npix(upnside) ; print npix
lmax=3*nside ; lmin=2
ell=arange(lmax+1)
fll=ell*(ell+1)/(2.*pi)

odisc=min(180.,180.*(24./lmax))
print odisc
# Out:
# 48
# 180.0

# %%
v=h.pix2vec(nside,cpixel)
spix=h.query_disc(nside,v,discsize,inclusive=inclusive,fact=fact)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-260-68bedf657e17> in <module>()
# ----> 1 spix=h.query_disc(nside,v,discsize,inclusive=inclusive,fact=fact)
#
# NameError: name 'v' is not defined

# %%
def approx_factorial(n):
    return sqrt(2.*pi*n)*((n/e)**n)*(1. + (1./(12.*n)) + (1./(288.*n*n)) - (139./(51840.*n*n*n)) - (571./(2488320.*n*n*n*n)))

def fnspfact(x):
    return 1./((x+2.)*(x+1.)*x*(x-1.))

def afact(n,m):
    if n==0:
        logn=0.
    else:
        logn=n*log(n)-n + 0.5*log(2.*pi*n) + log(1. +  (1./(12.*n)) + (1./(288.*n*n)) - (139./(51840.*n*n*n)) - (571./(2488320.*n*n*n*n)))
    
    if m==0:
        logm=0.
    else:
        logm=m*log(m)-m + 0.5*log(2.*pi*m) + log(1. +  (1./(12.*m)) + (1./(288.*m*m)) - (139./(51840.*m*m*m)) - (571./(2488320.*m*m*m*m)))
    print logn,logm
    return exp(logn - logm)

def calc_factorial_log(x):
    '''Uses the Stirling approximation to calculate the natural log of the factorial'''
    if x==0.:
        logxf=0.
    else:
        logxf=x*log(x)-x + 0.5*log(2.*pi*x) + log(1. +  (1./(12.*x)) + (1./(288.*x*x)) - (139./(51840.*x*x*x)) - (571./(2488320.*x*x*x*x)))
    return logxf

def return_nlm(l,m):
    '''Returns sqrt((l-m)!/(l+m)!)'''
    y=0.5*(calc_factorial_log(l-m) - calc_factorial_log(l+m) + calc_factorial_log(l-2) - calc_factorial_log(l+2))
    return exp(y)

# %%
l=30. ; m=2.
print approx_factorial(10.)
print sqrt(afact(l-m,l+m))
print fnspfact(l)
print return_nlm(l,m)
# Out:
# 3628799.97175
# 67.8897431371 81.5579594561
# 0.00107642688841
# 1.15869484613e-06
# 1.1586948461e-06

# %%
h.ringinfo(nside,(4*nside-1))

# %%
clr=h.read_cl("../../data/cl_rem3.fits")
random.seed(0) ; tqu=h.synfast(clr,nside,lmax=lmax,mmax=lmax,pol=True,new=True,verbose=False)
alm=h.map2alm(tqu,lmax=lmax,pol=True) ; teb=h.alm2map(alm,nside,pol=False)
cld=h.alm2cl(alm)
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
figure()
plot(ell,ell*(ell+1)*cld[1][:lmax+1]/(2.*pi),label="EE")
plot(ell,ell*(ell+1)*clr[1][:lmax+1]/(2.*pi),label="Thry EE")
plot(ell,ell*(ell+1)*cld[2][:lmax+1]/(2.*pi),label="r=0.001")
plot(ell,ell*(ell+1)*clr[2][:lmax+1]/(2.*pi),label="Thry BB")
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
y=rk.real_space_queb_kernels(nside,tmax=1.*odisc,maxlmax=3*nside,sampling=2500)
y.calc_qu2eb_rad_kernel(lmax,lmin)
y.calc_qu2queb_rad_kernel(lmax,lmin)
y.setup_taper(1.*odisc,0.001) ; y.setup_fn_rad_ker()

# %%
figure()
plot(y.theta*180./pi,y.fn_rad_ker(y.theta))
axhline(0.,color="k",ls="dashed")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rteb=y.convert_qu2eb(tqu,discsize=180.)
# Out:
# Computing on all pixels

# %%
h.mollview(teb[1])
h.mollview(rteb[2])
# Out:
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
cldr=h.alm2cl(h.map2alm(rteb,lmax=lmax))

# %%
figure()
plot(ell,cldr[1],"m-")
plot(ell,ell*(ell+1)*cld[1][:lmax+1]/(2.*pi),label="EE")
plot(ell,cldr[2],"b-")
plot(ell,ell*(ell+1)*cld[2][:lmax+1]/(2.*pi),label="r=0.001")
legend(loc=0)
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []
