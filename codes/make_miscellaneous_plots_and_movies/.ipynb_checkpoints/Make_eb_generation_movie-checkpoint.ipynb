# %%
import healpy as h
import sys  ; sys.path.append("../../codes/")
from modules import euler as euler
from modules import rs_rad_ker as rk
from modules import aliasing_correction as ac
from scipy.interpolate import interp1d

# %pylab notebook
import time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nside=256 ; npix=h.nside2npix(nside)
sampling=4500
lmax=2*nside

pxsize=np.sqrt(4.*pi/h.nside2npix(nside))
beta0=min(180,180.*32/(lmax))*np.pi/180. ; print beta0*180/pi

theta,pl2=rk.get_plm0(lmax,sampling,theta_max=min(pi,3.*beta0))
theta_cutoff=beta0

figpath="./figures/"
# !mkdir $figpath
# Out:
# 11.25
# mkdir: ./figures/: File exists

# %%
cltemp=h.read_cl("../../data/cl_rem3.fits")
cltemp=h.read_cl("../../data/planck_wp_highL_lensing_param.fits")
clr=[cltemp[0],cltemp[1],cltemp[2]*0.1,cltemp[3]*0]

def get_alm(cl,lmax,seed=0):
    random.seed(seed)
    almsize=h.Alm.getsize(lmax,lmax)
    ar=random.normal(size=almsize)
    ai=random.normal(size=almsize)
    alm=zeros(almsize,complex)
    for i in range(almsize):
        l,m=h.Alm.getlm(lmax,i)
        if m==0:
            alm[i]=complex(ar[i],0.)*sqrt(cl[l])
        else:
            alm[i]=complex(ar[i],ai[i])*sqrt(0.5*cl[l])
    return alm

almt=get_alm(clr[0],lmax,1) ; alme=get_alm(clr[1],lmax,2) ; almb=get_alm(clr[2],lmax,3)
true_alm=[almt,alme,almb] ; cltrue=h.alm2cl(true_alm)

tqu=h.alm2map(true_alm,nside,pol=True) ; alm=h.map2alm(tqu,lmax=lmax)
cl=h.alm2cl(alm) ; teb=h.alm2map(alm,nside,pol=False)

true_teb=h.alm2map(true_alm,nside,pol=False)
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
apow=rk.fn_apodization(theta,theta_cutoff=theta_cutoff,apow_frac=1.)
rad_ker=rk.calc_qu2eb_rad_ker(lmax,theta,pl2)# Default
rad_ker_i,rad_ker_d=rk.calc_qu2queb_rad_ker(lmax,theta,pl2)# Default
#rad_ker=rk.mod_rad_ker(theta,shift=0.05,amp=1,width=0.01,slope=2,expslope=2)# Modified

# %%
figure()
plot(theta,rad_ker)
plot(theta,rad_ker*apow,"--")
plot(theta,rad_ker_i,"--")
plot(theta,apow*max(rad_ker))
axvline(pxsize)
xlim(0,1.5*theta_cutoff)
rad_ker=rad_ker*apow
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fn_rad_ker=interp1d(np.cos(theta)[::-1],rad_ker[::-1],assume_sorted=True,kind="cubic",bounds_error=False,fill_value=0.0)
domega=4.*np.pi/float(npix)

# %%
lat=90
tmask=zeros(npix,float)
pmask=zeros(npix,float)
pindex=arange(npix)
theta0,phi0=h.pix2ang(nside,pindex)
theta0=theta0*180/pi ; phi0=phi0*180/pi
wband=15 ; phiband=15
tmask[theta0<lat-wband]=1 ; tmask[theta0>lat+wband]=1.
pmask[phi0<phiband]=1. ; pmask[phi0>360-phiband]=1.
mask=pmask*(1-tmask) ; fsky=sum(mask)/size(mask)

#h.mollview(mask)

lat=90
tmask=zeros(npix,float)
pmask=zeros(npix,float)
pindex=arange(npix)
theta0,phi0=h.pix2ang(nside,pindex)
theta0=theta0*180/pi ; phi0=phi0*180/pi
wband=8 ; phiband=8
tmask[theta0<lat-wband]=1 ; tmask[theta0>lat+wband]=1.
pmask[phi0<phiband]=1. ; pmask[phi0>360-phiband]=1.
mini_mask=pmask*(1-tmask) ; fsky=sum(mask)/size(mask)

h.gnomview(mask*0+mini_mask,rot=(0,0),xsize=500,reso=5,title="B mode",notext=True)
# Out:
# <img src="data:image/png;base64,..." width="580">

# %%
pix_list=nonzero(mask)[0]
print pix_list.size

print pix_list

random.shuffle(pix_list)
print pix_list
# Out:
# 17014
# [291328 291329 291330 ..., 495101 495102 495103]
# [417276 366065 356866 ..., 452126 494071 407063]

# %%
ctqu=ac.correct_aliasing(tqu[1],tqu[2],theta_cutoff,theta,rad_ker_i,iter=0,mask=mask)

# %%
cnt=1 ; plt_cnt=1 ; jump=5

e=np.zeros(npix,"double")
b=np.zeros(npix,"double")
#qe=np.zeros(npix,"double")
#ue=np.zeros(npix,"double")
#qb=np.zeros(npix,"double")
#ub=np.zeros(npix,"double")


random.shuffle(pix_list)
for i in pix_list:
    cosbeta,cos2alpha,sin2alpha,spix=euler.fn_s2euler_alpha(nside,i,theta_cutoff,inclusive=False,fact=4)
    gbeta=fn_rad_ker(cosbeta)
    cafb=cos2alpha*gbeta ; safb=sin2alpha*gbeta
    e[spix] = e[spix] + (-ctqu[1][i]*cafb + ctqu[2][i]*safb)*domega
    b[spix] = b[spix] + (-ctqu[1][i]*safb - ctqu[2][i]*cafb)*domega
    
    #qe[spix] = qe[spix] + (-ctqu[1][i]*cafb)*domega
    #ue[spix] = ue[spix] + (ctqu[2][i]*safb)*domega
    
    #qb[spix] = qb[spix] + (-ctqu[1][i]*safb)*domega
    #ub[spix] = ub[spix] + (-ctqu[2][i]*cafb)*domega
    
    cnt=cnt+1
    if mod(cnt,jump)==0:
        f=float(cnt)*100./size(pix_list)
        h.gnomview(e,rot=(0,0),xsize=500,reso=5,title="E mode [" + str(round(f,2)) + " %]",notext=True)
        savefig(figpath + "egen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        vmin=min(b[mini_mask!=0]) ; vmax=max(b[mini_mask!=0])
        h.gnomview(b,rot=(0,0),xsize=500,reso=5,min=vmin,max=vmax,title="B mode [" + str(round(f,2)) + " %]",notext=True)
        savefig(figpath + "bgen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        
        #h.gnomview(qe,rot=(0,0),xsize=500,reso=5,title="E mode",notext=True)
        #savefig(figpath + "qe_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        #h.gnomview(ue,rot=(0,0),xsize=500,reso=5,title="E mode",notext=True)
        #savefig(figpath + "ue_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        #h.gnomview(qb,rot=(0,0),xsize=500,reso=5,title="B mode",notext=True)
        #savefig(figpath + "qb_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        #h.gnomview(ub,rot=(0,0),xsize=500,reso=5,title="B mode",notext=True)
        #savefig(figpath + "ub_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        
        plt_cnt=plt_cnt+1
        if plt_cnt>20 and plt_cnt<30:
            jump=10
        elif plt_cnt>50 and plt_cnt<100:
            jump=100
        elif plt_cnt>100:
            jump=500
            
        #raw_input("")
    

# Padding in the end with repeated images of the final result so that it shows longer in the movie.
for i in range(5):
    h.gnomview(e,rot=(0,0),xsize=500,reso=5,title="E mode [" + str(round(f,2)) + " %]",notext=True)
    savefig(figpath + "egen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
    vmin=min(b[mini_mask!=0]) ; vmax=max(b[mini_mask!=0])
    h.gnomview(b,rot=(0,0),xsize=500,reso=5,min=vmin,max=vmax,title="B mode [" + str(round(f,2)) + " %]",notext=True)
    savefig(figpath + "bgen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
        
    #h.gnomview(qe,rot=(0,0),xsize=500,reso=5,title="E mode",notext=True)
    #savefig(figpath + "qe_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
    #h.gnomview(ue,rot=(0,0),xsize=500,reso=5,title="E mode",notext=True)
    #savefig(figpath + "ue_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
    #h.gnomview(qb,rot=(0,0),xsize=500,reso=5,title="B mode",notext=True)
    #savefig(figpath + "qb_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
    #h.gnomview(ub,rot=(0,0),xsize=500,reso=5,title="B mode",notext=True)
    #savefig(figpath + "ub_gen_"+str(plt_cnt).zfill(3) + ".pdf",dpi=150,bbox_inches="tight")
    
    plt_cnt=plt_cnt+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-054ab9701eac> in <module>()
#       1 cnt=1 ; plt_cnt=1 ; jump=5
#       2
# ----> 3 e=np.zeros(npix,"double")
#       4 b=np.zeros(npix,"double")
#       5 #qe=np.zeros(npix,"double")
#
# NameError: name 'np' is not defined
