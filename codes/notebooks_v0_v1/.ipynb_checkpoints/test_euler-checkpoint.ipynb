# %%
import healpy as h
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def return_euler(theta0,phi0,theta1,phi1):
    cosbeta=sin(theta0)*sin(theta1)*cos(phi1-phi0) + cos(theta0)*cos(theta1)
    beta=arccos(cosbeta)
    
    sa=sin(theta0)*sin(theta1)*sin(phi1-phi0)#/sqrt(1.-cosbeta*cosbeta)
    ca=(cos(theta0)*sin(theta1)*cos(phi1-phi0)-sin(theta0)*cos(theta1))#/sqrt(1.-cosbeta*cosbeta)
    alpha=arctan2(sa,ca)
    
    sg=-sin(theta0)*sin(phi1-phi0)#/sqrt(1.-cosbeta*cosbeta)
    cg=(cos(theta0)*sin(theta1) - cos(theta1)*sin(theta0)*cos(phi1-phi0))#/sqrt(1.-cosbeta*cosbeta)
    gamma=arctan2(sg,cg)
    return alpha,beta,gamma

def dumb_euler(theta0,phi0,theta1,phi1):
    return phi1-phi0,theta1-theta0,0.

# %%
nside=32
lmax=2*nside
almsize=h.Alm.getsize(lmax,lmax)

# %%
pixi=0 ; pixj=2000
thetai0=0.*pi/180 ; phii0=0.*pi/180 ; pixi=h.ang2pix(nside,thetai0,phii0)
thetaj0=90.*pi/180 ; phij0=45.*pi/180 ; pixj=h.ang2pix(nside,thetaj0,phij0)
print pixi,pixj
# Out:
# 0 6096

# %%
mi=zeros(h.nside2npix(nside),float) ; mi[pixi]=1.
mj=zeros(h.nside2npix(nside),float) ; mj[pixj]=1.
almi=h.map2alm(mi,lmax=lmax,mmax=lmax)
almj=h.map2alm(mj,lmax=lmax,mmax=lmax)
mi=h.alm2map(almi,nside)
mj=h.alm2map(almj,nside)

ralmi=zeros(almsize,complex)
ralmj=zeros(almsize,complex)
ralmi[:]=almi[:]
ralmj[:]=almj[:]
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
thetai,phii=h.pix2ang(nside,pixi) ; print thetai*180./pi,phii*180./pi
thetaj,phij=h.pix2ang(nside,pixj) ; print thetaj*180./pi,phij*180./pi
alpha,beta,gamma=return_euler(thetai,phii,thetaj,phij) ; print alpha*180./pi,beta*180./pi,gamma*180./pi
alpha,beta,gamma=dumb_euler(thetai,phii,thetaj,phij) ; print alpha*180./pi,beta*180./pi,gamma*180./pi
# Out:
# 1.46197116265 45.0
# 90.0 46.40625
# 1.40670772877 88.5384692513 -0.0358863523023
# 1.40625 88.5380288374 0.0

# %%
ralmi[:]=almi[:]

# %%
h.rotate_alm(ralmi,alpha,beta,gamma,lmax=lmax)
rmi=h.alm2map(ralmi,nside)
#h.rotate_alm(ralmj,gamma,beta,alpha,lmax=lmax)
#rmj=h.alm2map(ralmj,nside)
h.mollview(rmi)
h.mollview(mi)
# Out:
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
h.mollview(mj)
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
h.rotate_alm?
