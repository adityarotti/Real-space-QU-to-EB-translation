# %%
import healpy as h
from scipy.integrate import quad
import os
import sys  ; sys.path.append("../../codes/")
from modules_v0 import local_eb_kernel as rk

import timeit

# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from matplotlib import rcParams,rc
params = {'backend': 'pdf',
          'savefig.dpi': 200,
          'axes.labelsize': 15,
          'text.fontsize': 15,
          'axes.linewidth' : 2,
          'lines.linewidth' : 2,
          'font.size': 15,
          'xtick.labelsize': 15,
          'ytick.major.pad': 6,
          'xtick.major.pad': 6,
          'ytick.labelsize': 15,
          'text.usetex': True,
          'font.family':'sans-serif',
          'font.sans-serif':'FreeSans'}
rc('text.latex', preamble='\usepackage{sfmath}')
rcParams.update(params)
# Out:
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/matplotlib/__init__.py:913: UserWarning: text.fontsize is deprecated and replaced with font.size; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
lmin=2
nside=256

lmaxl=2*nside ; lmaxh=3*nside
yl=rk.real_space_queb_kernels(nside,tmax=180.,maxlmax=4*nside,sampling=4000)
yl.calc_qu2eb_rad_kernel(lmaxl,lmin)
yl.calc_qu2queb_rad_kernel(lmaxl,lmin)
yl.setup_fn_rad_ker()


yh=rk.real_space_queb_kernels(nside,tmax=180.,maxlmax=4*nside,sampling=4000)
yh.calc_qu2eb_rad_kernel(lmaxh,lmin)
yh.calc_qu2queb_rad_kernel(lmaxh,lmin)
yh.setup_fn_rad_ker()

f=float(lmaxl)/float(lmaxh)
print f

# %%
figure()
plot(yh.theta*180./pi,(yh.theta**-2)*yh.fn_rad_ker(yh.theta)/yh.omega,"b-")
plot(yh.theta*180./pi,0.01/(yh.theta)**3.,"r-")
#loglog()
ylim(-100,100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in power
#   from ipykernel import kernelapp as app
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in multiply
#   from ipykernel import kernelapp as app
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:3: RuntimeWarning: divide by zero encountered in divide
#   app.launch_new_instance()
# (-100, 100)

# %%
figure()
plot(yl.theta*180./pi,yl.fn_rad_ker(yl.theta)/yl.omega,"r-")
plot(yh.theta*180./pi,yh.fn_rad_ker(yh.theta)/yh.omega,"b-")
plot(yh.theta*180./pi,yh.fn_rad_ker(yh.theta*f)*f*f/yh.omega,"g-.")
plot(yl.theta*180./pi,yl.fn_rad_ker(yl.theta/f)/f/f/yl.omega,"m-.")


xlim(0,5)
ylim(-1000,20000)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1000, 20000)

# %%
figure()
plot(yh.theta*180./pi,yh.fn_rad_ker(yh.theta)/max(yh.rad_ker),"r-",alpha=0.2)
plot(yh.theta*180./pi,(yh.fn_rad_ker(yh.theta)-yl.fn_rad_ker(yh.theta*lmaxh/lmaxl)*((lmaxh*1./lmaxl)**2.))/max(yh.rad_ker),"g--")
plot(yl.theta*180./pi,yl.fn_rad_ker(yl.theta)/max(yl.rad_ker),"b-",alpha=0.2)
plot(yl.theta*180./pi,(yl.fn_rad_ker(yl.theta)-yh.fn_rad_ker(yh.theta*lmaxl/lmaxh)*((lmaxl*1./lmaxh)**2.))/max(yl.rad_ker),"m--")

xlim(0,15)
ylim(-.01,.01)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-0.01, 0.01)

# %%
15/4.
# Out:
# 3.75

# %%
f1=y2.fn_rad_ker_p2(y2.theta)/y2.omega
f12=y2.fn_rad_ker_p2(y2.theta/f)/f/f/y2.omega
f2=y4.fn_rad_ker_p2(y4.theta)/y4.omega
f21=y4.fn_rad_ker_p2(y4.theta*f)*f*f/y4.omega

figure()
plot(y4.theta*180/pi, f2 ,"m-")
plot(y4.theta*180/pi, f12 ,"c--")
plot(y4.theta*180/pi, f1 ,"r-")
plot(y4.theta*180/pi, f21 ,"g--")

xlim(0.1,30)
#semilogx()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.1, 30)

# %%
f1=y2.fn_rad_ker_m2(y2.theta)/y2.omega
f12=y2.fn_rad_ker_m2(y2.theta/f)/f/f/y2.omega
f2=y4.fn_rad_ker_m2(y4.theta)/y4.omega
f21=y4.fn_rad_ker_m2(y4.theta*f)*f*f/y4.omega

figure()
plot(y4.theta*180/pi, f2 ,"m-")
plot(y4.theta*180/pi, f12 ,"c--")
plot(y4.theta*180/pi, f1 ,"r-")
plot(y4.theta*180/pi, f21 ,"g--")

xlim(0.1,30)
semilogx()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
f1=y2.fn_rad_ker(y2.theta)/y2.omega
f12=y2.fn_rad_ker(y2.theta/f)/f/f/y2.omega
f2=y4.fn_rad_ker(y4.theta)/y4.omega
f21=y4.fn_rad_ker(y4.theta*f)*f*f/y4.omega

figure()
plot(y4.theta*180/pi, f2 ,"m-")
plot(y4.theta*180/pi, f12 ,"c--")
plot(y4.theta*180/pi, f1 ,"r-")
plot(y4.theta*180/pi, f21 ,"g--")

xlim(0.1,30)
semilogx()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
a1=5000 ;  a2=20
figure()
plot(yl.theta,sin(a1*yl.theta)/((a2*yl.theta))**1.5)
plot(yl.theta,sin(a2*yl.theta)/((a2*yl.theta))**1.5)
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:3: RuntimeWarning: invalid value encountered in divide
#   app.launch_new_instance()
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in divide
# []
